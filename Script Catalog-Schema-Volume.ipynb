# %% [markdown]
# 1. Creo el catalogo del Proyecto Final DMC Databricks Associate

# %%
# %sql
CREATE CATALOG IF NOT EXISTS proyecto_final_dmc;

# %% [markdown]
# 2. Creo los esquemas necesarios para el proyecto

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS proyecto_final_dmc.landing;
CREATE SCHEMA IF NOT EXISTS proyecto_final_dmc.bronze;
CREATE SCHEMA IF NOT EXISTS proyecto_final_dmc.silver;
CREATE SCHEMA IF NOT EXISTS proyecto_final_dmc.gold;

# %% [markdown]
# 3. Creo el Volume para los archivos batch

# %%
# %sql
CREATE VOLUME IF NOT EXISTS proyecto_final_dmc.landing.raw_data;

# %% [markdown]
# 4. Creo los directorios o subcarpetas donde se alojarán los archivos

# %%
dbutils.fs.mkdirs("/Volumes/proyecto_final_dmc/landing/raw_data/clientes")
dbutils.fs.mkdirs("/Volumes/proyecto_final_dmc/landing/raw_data/productos")
dbutils.fs.mkdirs("/Volumes/proyecto_final_dmc/landing/raw_data/pedidos")
dbutils.fs.mkdirs("/Volumes/proyecto_final_dmc/landing/raw_data/detalle_pedidos")
